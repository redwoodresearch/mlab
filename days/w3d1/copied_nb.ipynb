# %%
# %load_ext autoreload
# %autoreload 2

# %%
import transformers
import importlib
import torch as t
import GPTJComponent

# %%
model = transformers.AutoModelForSequenceClassification.from_pretrained("EleutherAI/gpt-j-6B")
model.eval()
# Out:
# [autoreload of GPTJComponent failed: Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# ...

# %%
model
# Out:
# GPTJForSequenceClassification(
#   (transformer): GPTJModel(
#     (wte): Embedding(50400, 4096)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0): GPTJBlock(
#         (ln_1): LayerNorm((4096,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTJAttention(
#           (attn_dropout): Dropout(p=0.0, inplace=False)
#           (resid_dropout): Dropout(p=0.0, inplace=False)
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (out_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): GPTJMLP(
#           (fc_in): Linear(in_features=4096, out_features=16384, bias=True)
#           (fc_out): Linear(in_features=16384, out_features=4096, bias=True)
#           (dropout): Dropout(p=0.0, inplace=False)
#         )
#       )
# ...

# %%
# model.transformer.wte
# model.transformer.drop
# model.transformer.h[0...27]
# model.transformer.ln_f # 
# model.score ???

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")

# %%
tokens = tokenizer.encode("Two tokens")
tokens_tensor = t.tensor(tokens).unsqueeze(0)
# Out:
# [autoreload of GPTJComponent failed: Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]

# %%
model.eval()
components = [GPTJComponent.GPTJComponent(i, model) for i in range(4)]
x = tokens_tensor.clone()
x2 = tokens_tensor.clone()

for i in range(4):
    print(i)
    x = components[i](x)

x2 = model(x2, output_hidden_states=True)

# t.isclose(x, x2)
# Out:
# [autoreload of GPTJComponent failed: Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/lib/python3/dist-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 0 free vars, not 1
# ]
# 0
# 1
# 2
# 3

# %%
print(x[1], x2.logits)

t.isclose(x[1], x2.logits) ## .hidden_states[-1]) ## .shape) # .logits.
# shape)

# for t in [x - x2, x, x2]:
    # print(t.linalg.norm(t))

# x2
# Out:
# tensor([[[1.2060, 1.1705],
#          [3.7457, 0.3129]]], grad_fn=<UnsafeViewBackward0>) tensor([[3.7457, 0.3129]], grad_fn=<IndexBackward0>)
# tensor([[[False, False],
#          [ True,  True]]])

# %%
# This is slow, beware! ~20 seconds
print("Begin getting IMDB...",end="")
import torchtext
data_train, data_test = torchtext.datasets.IMDB(root=".data", split=("train", "test"))
data_train = list(data_train)
data_test = list(data_test)
print("done")
# Out:
# Begin getting IMDB...done

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-1e203f80b5c9> in <module>
#       1 tokenizer = transformers.AutoTokenizer.from_pretrained("EleutherAI/gpt-j-6B")
# ----> 2 transformers.GPTJTokenizerFast
#
# ~/.local/lib/python3.8/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    2425             value = getattr(module, name)
#    2426         else:
# -> 2427             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#    2428
#    2429         setattr(self, name, value)
#
# AttributeError: module transformers has no attribute GPTJTokenizerFast

# %%
num_batches = 1000
processed_data = []
all_texts = [dt[1] for dt in data_train]
print("Begin processing...",end="")
tokenized = tokenizer(all_texts)
print("done.")
# Out:
# Begin processing...done.

# %%
tokenized
